# %%
from experiments import draw_h, experiment
# auto load
# %load_ext autoreload

# %%
draw_h(type='mul')

# %%
draw_h(type='add')

# %%
for i in [1,2,4,8,16,32,64]:
    experiment(type = 'add', r=i)
# Out:
# est rank: 2
# trainbale: 0.005859375
# exp rank: 2.0
# est rank: 4
# trainbale: 0.01171875
# exp rank: 4.0
# est rank: 8
# trainbale: 0.0234375
# exp rank: 8.0
# est rank: 16
# trainbale: 0.046875
# exp rank: 16.0
# est rank: 32
# trainbale: 0.09375
# exp rank: 32.0
# est rank: 64
# trainbale: 0.1875
# exp rank: 64.0
# est rank: 128
# trainbale: 0.375
# exp rank: 128.0

# %%
for i in [1,2,4,8,16,32,64]:
    experiment(type = 'mul', r=i)
# Out:
# est rank: 1
# trainbale: 0.005859375
# exp rank: 1.0
# est rank: 2
# trainbale: 0.01171875
# exp rank: 2.0
# est rank: 4
# trainbale: 0.0234375
# exp rank: 4.0
# est rank: 8
# trainbale: 0.046875
# exp rank: 8.0
# est rank: 16
# trainbale: 0.09375
# exp rank: 16.0
# est rank: 32
# trainbale: 0.1875
# exp rank: 32.0
# est rank: 64
# trainbale: 0.375
# exp rank: 64.0

# %%
for i in [2,4,8,16,32,64]:
    experiment(type = 'h_mul', r=i,k=2)
# Out:
# est rank: 1
# trainbale: 0.01171875
# exp rank: 1.0
# est rank: 4
# trainbale: 0.0234375
# exp rank: 4.0
# est rank: 16
# trainbale: 0.046875
# exp rank: 16.0
# est rank: 64
# trainbale: 0.09375
# exp rank: 64.0
# est rank: 256
# trainbale: 0.1875
# exp rank: 256.0
# est rank: 256
# trainbale: 0.375
# exp rank: 256.0

# %%
for i in [1,2,4,8,16,32]:
    experiment(type = 'h_mul', r=3*i,k=3)
# Out:
# est rank: 1
# trainbale: 0.017578125
# exp rank: 1.0
# est rank: 8
# trainbale: 0.03515625
# exp rank: 8.0
# est rank: 64
# trainbale: 0.0703125
# exp rank: 64.0
# est rank: 256
# trainbale: 0.140625
# exp rank: 256.0
# est rank: 256
# trainbale: 0.28125
# exp rank: 256.0
# est rank: 256
# trainbale: 0.5625
# exp rank: 256.0

# %%
for i in [1,2,4,8,16,32]:
    experiment(type = 'h_add', r=3*i,k=3)
# Out:
# est rank: 8
# trainbale: 0.017578125
# exp rank: 8.0
# est rank: 64
# trainbale: 0.03515625
# exp rank: 28.0
# est rank: 256
# trainbale: 0.0703125
# exp rank: 104.0
# est rank: 256
# trainbale: 0.140625
# exp rank: 256.0
# est rank: 256
# trainbale: 0.28125
# exp rank: 256.0
# est rank: 256
# trainbale: 0.5625
# exp rank: 256.0
